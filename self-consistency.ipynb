# %% [markdown]
# ### Self-Consistency and Multiple Paths of Reasoning Tutorial
# #### Overview
# This tutorial explores the concept of self-consistency and multiple paths of reasoning in prompt engineering. We'll focus on techniques for generating diverse reasoning paths and aggregating results to improve the quality and reliability of AI-generated answers.
#
# #### Motivation
# Large language models can sometimes produce inconsistent or unreliable outputs. By leveraging multiple reasoning paths and aggregating results, we can enhance the robustness and accuracy of AI-generated responses. This approach is particularly useful for complex problem-solving tasks where a single path of reasoning might be insufficient or prone to errors.
#
# #### Key Components
# Generating multiple reasoning paths
# Aggregating results for better answers
# Implementing self-consistency checks
# Applying these techniques to various problem-solving scenarios

# %%
import os
from langchain_openai import ChatOpenAI
from langchain.prompts import PromptTemplate
from dotenv import load_dotenv
import random
from collections import Counter

# Load environment variables
load_dotenv()

# Set up OpenAI API key
os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY')

# Initialize the language model
llm = ChatOpenAI(model="gpt-4o-mini")

# %% [markdown]
# #### Method Details
# Our approach involves the following steps:
#
# Setting up the environment with necessary libraries (OpenAI and LangChain)
#
# Designing prompts that encourage diverse reasoning paths
#
# Generating multiple responses using these prompts
#
# Implementing aggregation methods to combine and analyze the generated responses
#
# Applying self-consistency checks to evaluate the reliability of the results
#
# Demonstrating the effectiveness of this approach on various problem types
#
# Throughout the tutorial, we'll use practical examples to illustrate how these techniques can be applied to enhance the quality and reliability of AI-generated answers.

# %% [markdown]
# ### Generating Multiple Reasoning Paths
# Let's create a function that generates multiple reasoning paths for a given problem.

# %%
def generate_multiple_paths(problem, num_paths=3):
    """
    Generate multiple reasoning paths for a given problem.
    
    Args:
    problem (str): The problem statement.
    num_paths (int): Number of reasoning paths to generate.
    
    Returns:
    list: A list of generated reasoning paths.
    """
    prompt_template = PromptTemplate(
        input_variables=["problem", "path_number"],
        template="""Solve the following problem using a unique approach. This is reasoning path {path_number}.
        Problem: {problem}
        Reasoning path {path_number}:"""
    )

    paths = []
    for i in range(num_paths):
        chain = prompt_template | llm
        response = chain.invoke({"problem": problem, "path_number": i+1}).content
        paths.append(response)
    
    return paths

# %%
problem = "A ball is thrown upwards with an initial velocity of 20 m/s. How high will it go?"
paths = generate_multiple_paths(problem)

for i, path in enumerate(paths, 1):
    print(f"Path {i}:\n{path}\n")
# Out:
# Path 1:
# To solve the problem using Reasoning Path 1, we can utilize the principles of physics, particularly kinematics, to find the maximum height reached by the ball.
#
# 1. **Identify the given values:**
#    - Initial velocity (\( u \)) = 20 m/s
#    - Final velocity at the maximum height (\( v \)) = 0 m/s (since the ball momentarily stops at its peak)
#    - Acceleration due to gravity (\( a \)) = -9.81 m/s² (the negative sign indicates that gravity acts downwards)
#
# 2. **Use the kinematic equation:**
#    One of the kinematic equations relates initial velocity, final velocity, acceleration, and displacement (height in this case):
#    \[
#    v^2 = u^2 + 2a s
#    \]
#    where:
#    - \( s \) is the displacement (maximum height),
#    - \( u \) is the initial velocity,
#    - \( v \) is the final velocity,
#    - \( a \) is the acceleration.
#
# 3. **Substitute the values:**
#    Plugging in the given values:
#    \[
#    0^2 = (20 \, \text{m/s})^2 + 2(-9.81 \, \text{m/s}^2) s
#    \]
#
#    Simplifying:
#    \[
#    0 = 400 - 19.62s
#    \]
#
# 4. **Solve for \( s \):**
#    Rearranging the equation to find \( s \):
#    \[
#    19.62s = 400
#    \]
#    \[
#    s = \frac{400}{19.62} \approx 20.39 \, \text{m}
#    \]
#
# 5. **Conclusion:**
#    The maximum height that the ball will reach is approximately **20.39 meters**. This unique approach combines understanding of kinematic equations with a straightforward substitutive calculation, allowing for a clear solution to the problem.
#
# Path 2:
# To find the maximum height that the ball reaches when thrown upwards with an initial velocity of 20 m/s, we can use the principles of kinematics and the concept of energy conservation. Here's a unique approach using the energy conservation method:
#
# ### Step 1: Understand the energy concepts
# When the ball is thrown upwards, it possesses kinetic energy due to its initial velocity. As it ascends, this kinetic energy is converted into gravitational potential energy until it reaches its maximum height, where the velocity becomes 0 m/s.
#
# ### Step 2: Kinetic Energy at launch
# The initial kinetic energy (KE) of the ball can be calculated using the formula:
# \[
# KE = \frac{1}{2} mv^2
# \]
# where:
# - \(m\) = mass of the ball (we will keep it as a variable since it will cancel out),
# - \(v\) = initial velocity (20 m/s).
#
# So, the kinetic energy at launch is:
# \[
# KE = \frac{1}{2} m (20)^2 = 200m \, \text{Joules}
# \]
#
# ### Step 3: Gravitational Potential Energy at maximum height
# At the maximum height (H), the ball’s velocity is 0, and all the kinetic energy has been converted into gravitational potential energy (PE). The potential energy can be expressed as:
# \[
# PE = mgh
# \]
# where:
# - \(g\) = acceleration due to gravity (approximately \(9.81 \, \text{m/s}^2\)),
# - \(h\) = height (which we want to find).
#
# At the maximum height, the total energy is conserved, meaning:
# \[
# KE = PE
# \]
# So we have:
# \[
# 200m = mgh
# \]
#
# ### Step 4: Solve for the height (H)
# We can cancel \(m\) from both sides of the equation (assuming \(m \neq 0\)):
# \[
# 200 = gh
# \]
# Now, plug in the value of \(g\):
# \[
# 200 = (9.81)h
# \]
# To find \(h\), rearrange the equation:
# \[
# h = \frac{200}{9.81} \approx 20.39 \, \text{meters}
# \]
#
# ### Conclusion
# Thus, the maximum height that the ball will reach when thrown upwards with an initial velocity of 20 m/s is approximately **20.39 meters**. This unique approach using energy conservation provides a clear understanding of the problem by focusing on the conversion between kinetic and potential energy.
#
# Path 3:
# To solve the problem of how high a ball will go when thrown upwards with an initial velocity of 20 m/s, we can use the principles of physics, specifically the equations of motion under constant acceleration due to gravity. However, since you've asked for a unique approach, let’s use energy conservation instead.
#
# ### Steps using Energy Conservation:
#
# 1. **Determine Initial Kinetic Energy**:
#    The initial kinetic energy (KE_initial) of the ball when it is thrown can be calculated using the formula:
#    \[
#    KE = \frac{1}{2} mv^2
#    \]
#    Here, \(m\) is the mass of the ball (which we do not need to know, as it will cancel out) and \(v\) is the initial velocity (20 m/s). Thus, we have:
#    \[
#    KE_{initial} = \frac{1}{2} m (20)^2 = 200m \text{ (Joules, where } m \text{ is in kg)}
#    \]
#
# 2. **Determine Potential Energy at the Maximum Height**:
#    As the ball rises, its kinetic energy is converted into gravitational potential energy (PE) at the maximum height (h). The potential energy can be given by:
#    \[
#    PE = mgh
#    \]
#    Where \(g\) is the acceleration due to gravity (approximately \(9.81 \, m/s^2\)). At the maximum height, all the kinetic energy will have been converted into potential energy, so:
#    \[
#    PE_{max} = mgh
#    \]
#
# 3. **Apply Energy Conservation**:
#    At the launch point:
#    \[
#    KE_{initial} = PE_{max}
#    \]
#    Plugging in the expressions we have:
#    \[
#    200m = mgh
#    \]
#    The masses \(m\) can be canceled out (assuming \(m \neq 0\)):
#    \[
#    200 = gh
#    \]
#    Now we can solve for \(h\):
#    \[
#    h = \frac{200}{g} = \frac{200}{9.81} \approx 20.39 \text{ meters}
#    \]
#
# 4. **Conclusion**:
#    The maximum height \(h\) that the ball will reach when thrown upwards with an initial velocity of 20 m/s is approximately **20.39 meters**.
#
# This unique approach highlights the relationship between kinetic energy and potential energy, providing a clear method to solve the problem without directly using kinematic equations.

# %% [markdown]
# #### Aggregating Results
# Now that we have multiple reasoning paths, let's create a function to aggregate the results and determine the most consistent answer.

# %%
def aggregate_results(paths):
    """
    Aggregate results from multiple reasoning paths.
    
    Args:
    paths (list): List of reasoning paths.
    
    Returns:
    str: The most consistent answer.
    """
    prompt_template = PromptTemplate(
        input_variables=["paths"],
        template="""Analyze the following reasoning paths and determine the most consistent answer. If there are discrepancies, explain why and provide the most likely correct answer.
        Reasoning paths:`
        {paths}
        
        Most consistent answer:"""
    )

    chain = prompt_template | llm
    response = chain.invoke({"paths": "\n".join(paths)}).content
    return response

# %%
aggregated_result = aggregate_results(paths)
print("Aggregated Result:\n", aggregated_result)
# Out:
# Aggregated Result:
#  After analyzing the provided reasoning paths, both approaches to solving the problem yield the same result: the maximum height reached by a ball thrown upwards with an initial velocity of 20 m/s is approximately **20.39 meters**. Here’s a summary of the reasoning and conclusions from both paths:
#
# ### Reasoning Path 1: Kinematic Equations
# 1. **Given Values**: Initial velocity (\(u = 20 \, \text{m/s}\)), final velocity at maximum height (\(v = 0 \, \text{m/s}\)), and acceleration due to gravity (\(a = -9.81 \, \text{m/s}^2\)).
# 2. **Kinematic Equation**: Used the equation \(v^2 = u^2 + 2as\) to solve for height \(s\).
# 3. **Calculation**: Arriving at the conclusion \(s \approx 20.39 \, \text{m}\).
#
# ### Reasoning Path 2: Energy Conservation
# 1. **Energy Concepts**: Evaluated the conversion of kinetic energy into potential energy.
# 2. **Kinetic Energy Calculation**: The ball’s kinetic energy at launch was calculated as \(200m \, \text{Joules}\).
# 3. **Potential Energy at Maximum Height**: Set the equation \(200m = mgh\) and solved for height \(h\).
# 4. **Calculation**: Also concluded that \(h \approx 20.39 \, \text{meters}\).
#
# ### Discrepancies and Conclusion
# - **Discrepancies**: None were found between the two paths; both methods consistently provided the same maximum height value of approximately **20.39 meters**.
# - **Most Consistent Answer**: The maximum height reached by the ball thrown upwards with an initial velocity of 20 m/s is indeed **approximately 20.39 meters**.
#
# The consistency across both reasoning paths confirms the reliability of the calculations and the applicability of both kinematic equations and energy conservation principles in solving this problem.

# %% [markdown]
# #### Self-Consistency Check
# To further improve our results, let's implement a self-consistency check that evaluates the reliability of our aggregated answer.

# %%
def self_consistency_check(problem, aggregated_result):
    """
    Perform a self-consistency check on the aggregated result.
    
    Args:
    problem (str): The original problem statement.
    aggregated_result (str): The aggregated result to check.
    
    Returns:
    str: An evaluation of the result's consistency and reliability.
    """
    prompt_template = PromptTemplate(
        input_variables=["problem", "result"],
        template="""Evaluate the consistency and reliability of the following result for the given problem.
        Problem: {problem}
        Result: {result}
        
        Evaluation (consider factors like logical consistency, adherence to known facts, and potential biases):"""
    )

    chain = prompt_template | llm
    response = chain.invoke({"problem": problem, "result": aggregated_result}).content
    return response

# %%
consistency_evaluation = self_consistency_check(problem, aggregated_result)
print("Self-Consistency Evaluation:\n", consistency_evaluation)
# Out:
# Self-Consistency Evaluation:
#  The evaluation of the result regarding the maximum height reached by a ball thrown upwards with an initial velocity of \(20 \, \text{m/s}\) reveals a few important aspects regarding the consistency and reliability of the conclusion.
#
# ### Logical Consistency
# 1. **Kinematic Equations**: The derivation using kinematic equations is appropriate and follows a logical sequence:
#    - The use of the equation \(v^2 = u^2 + 2as\) to find the maximum height (where final velocity \(v=0\) at max height) is standard.
#    - Plugging in the values gives:
#      \[
#      0 = (20)^2 + 2(-9.81)s \implies 0 = 400 - 19.62s \implies 19.62s = 400 \implies s \approx 20.39 \, \text{meters}.
#      \]
#    - This correctly leads to the conclusion of approximately \(20.39\) meters.
#
# 2. **Energy Conservation**: The energy conservation approach is also sound:
#    - The kinetic energy at the launch was calculated correctly as \(\frac{1}{2}mv^2\), leading to \(KE = 200m\) (correct if mass is taken as 1 kg for simplicity).
#    - Setting this equal to the gravitational potential energy \(PE = mgh\) and solving indeed gives:
#      \[
#      200m = mgh \implies h = \frac{200}{g} \approx 20.39 \, \text{meters}.
#      \]
#    - This confirms the height based on energy conservation is simultaneously valid.
#
# ### Adherence to Known Facts
# - The calculations adhere to classical mechanics principles, specifically the kinematic equations and the work-energy theorem.
# - The value of \(g = 9.81 \, \text{m/s}^2\) is correctly used, which is a widely accepted value for gravitational acceleration near the Earth's surface.
#
# ### Potential Biases
# - There are no apparent biases in this evaluation since both methods yield consistent results without any conflicting assumptions or overlooked factors.
# - The calculations follow universally accepted physics principles, and no approximations or assumptions that might skew results were made.
#
# ### Conclusion
# Overall, the evaluation of the maximum height reached by the ball being approximately **20.39 meters** is both consistent and reliable based on:
# - Logical consistency and clarity in the path of reasoning.
# - Correct application of established physical laws (kinematics and conservation of energy).
# - Absence of discrepancies between different problem-solving approaches.
#
# Thus, we can conclude that the result is valid and trustworthy for practical understanding in the context of classical mechanics.

# %%
def solve_problem(problem):
    """
    Solve a problem using multiple reasoning paths, aggregation, and self-consistency check.
    
    Args:
    problem (str): The problem statement.
    
    Returns:
    tuple: (aggregated_result, consistency_evaluation)
    """
    paths = generate_multiple_paths(problem)
    aggregated_result = aggregate_results(paths)
    consistency_evaluation = self_consistency_check(problem, aggregated_result)
    return aggregated_result, consistency_evaluation

# Example problems
problems = [
    "What is the capital of France?",
    "Explain the concept of supply and demand in economics.",
    "If a train travels at 60 km/h, how long will it take to cover 180 km?"
]

for problem in problems:
    print(f"Problem: {problem}")
    result, evaluation = solve_problem(problem)
    print("Aggregated Result:\n", result)
    print("\nConsistency Evaluation:\n", evaluation)
    print("\n" + "-"*50 + "\n")
# Out:
# Problem: What is the capital of France?
# Aggregated Result:
#  The most consistent answer across all three reasoning paths is **Paris**.
#
# **Discrepancies and Explanation:**
# 1. All reasoning paths consistently point towards Paris by highlighting different aspects: historical context, cultural significance, geography, and political importance.
# 2. None of the paths provide conflicting information or alternatives; each reinforces the notion that Paris is the capital by showcasing its unique characteristics and significance.
# 3. The conclusion across all three paths is aligned, solidifying Paris as the capital without any contradictions.
#
# By synthesizing these perspectives, it's clear that the reasoning solidly supports the answer of **Paris** without any discrepancies.
#
# Consistency Evaluation:
#  The evaluation of the consistency and reliability of the result regarding the capital of France, which is identified as **Paris**, reveals several positive aspects. Here are the key factors:
#
# 1. **Logical Consistency**:
#    - The reasoning paths provided do not present any contradictions. Each path builds upon the others, creating a cohesive narrative that consistently points to Paris as the capital. The logical flow of reasoning across different aspects (historical, cultural, geographical, and political) supports the conclusion, indicating strong internal consistency.
#
# 2. **Adherence to Known Facts**:
#    - The result adheres to well-established factual knowledge. Paris is widely recognized and accepted as the capital of France, substantiated by constitutional, historical, and administrative factors. The absence of conflicting information further strengthens the reliability of the result.
#
# 3. **Potential Biases**:
#    - While the evaluation does not indicate any overt biases, it does rely on common perceptions and interpretations of Paris's significance. However, these interpretations are closely aligned with widely accepted facts, minimizing the risk of bias affecting the outcome. That said, if the reasoning paths had drawn on subjective or unverified claims, it might have introduced bias; since they lean on established facts and historical context, this risk appears mitigated.
#
# 4. **Comprehensive Coverage**:
#    - The reasoning paths encompass a range of factors that reinforce the identity of Paris as the capital, suggesting a thorough and well-rounded approach to the question. The inclusion of different dimensions (historical, cultural, geographical) ensures that the answer is not one-dimensional and provides a deeper understanding of why Paris holds its designation.
#
# 5. **Conclusion**:
#    - Overall, the evaluation suggests that the result declaring **Paris** as the capital of France is highly consistent and reliable. Given that all reasoning paths converge towards the same conclusion without any discrepancies or conflicting information, the result stands as a robust affirmation of a well-established fact. Thus, the reasoning reflects a strong adherence to known truths, logical consistency, and a comprehensive perspective that encompasses various relevant aspects of the subject matter.
#
# --------------------------------------------------
#
# Problem: Explain the concept of supply and demand in economics.
# Aggregated Result:
#  The most consistent answer among the reasoning paths provided revolves around the fundamental concepts of supply and demand in economics and how they interact to establish market equilibrium.
#
# ### Summary of Key Points:
#
# 1. **Fundamentals of Supply and Demand**:
#    - **Supply** refers to the quantity of a good or service that producers are willing to sell at various prices. It increases as prices rise and decreases when prices drop.
#    - **Demand** refers to the quantity of a good or service that consumers are willing to purchase at different prices. It follows the law of demand, where demand increases as prices decrease and vice versa.
#
# 2. **Market Equilibrium**:
#    - Equilibrium is achieved when the quantity of goods supplied equals the quantity of goods demanded at a certain price, resulting in no shortages or surpluses.
#
# 3. **Shifts and Dynamics**:
#    - Both supply and demand can shift due to various external influences (e.g., consumer trends, production costs, weather conditions). For instance, an increase in consumer preference for a product will shift the demand curve to the right, potentially leading to a new equilibrium at a higher price point.
#    - Similarly, factors impacting production costs, like a shortage of key ingredients, can shift the supply curve leftward, resulting in reduced supply and higher prices.
#
# 4. **Real-World Analogies**:
#    - The reasoning paths support the fundamental concepts using relatable analogies, such as comparing supply to a bakery's production and demand to concert ticket sales. These analogies help illustrate how changes in one side can influence the other.
#
# ### Evaluation of Discrepancies:
# - Both Reasoning Paths 1 and 2 effectively convey the fundamental concepts of supply and demand, but they differ in style. Path 1 uses a visualization of a marketplace, while Path 2 employs analogies to common scenarios.
# - The dance analogy is informative and creative (last paragraph), but it strays slightly from directly addressing market concepts, which may confuse some readers while providing an interesting perspective.
#
# ### Conclusion:
# Ultimately, the most consistent answer emerges from combining the essential elements across all paths: understanding how supply and demand interact, the concept of equilibrium, and the implications of shifts in these curves. The explanations via visualizations, real-world analogies, and conceptual dance effectively illustrate the dynamic interplay of supply and demand but should maintain a focus on their economic significance.
#
# Thus, the consistent understanding is that supply and demand are fundamental to pricing systems and market behavior, regardless of the method used to illustrate it.
#
# Consistency Evaluation:
#  ### Evaluation of Consistency and Reliability
#
# #### Logical Consistency:
# The response is logically coherent and effectively outlines the fundamental principles of supply and demand in economics. It clearly delineates the definitions of supply and demand, how they operate independently and interactively, and the concept of market equilibrium. The straightforward explanation of these constructs is essential for understanding the basic mechanics of economic theory.
#
# 1. **Fundamentals of Supply and Demand**:
#    - The definitions of supply and demand are accurate and align with standard economic theory. The law of supply and demand is correctly stated, confirming the expected behavior of producers and consumers relative to price changes.
#
# 2. **Market Equilibrium**:
#    - The explanation of market equilibrium is well-articulated, highlighting the balance between supply and demand. This concept is a cornerstone of market economics and is presented without inconsistencies.
#
# 3. **Shifts and Dynamics**:
#    - The discussion on how various factors impact supply and demand is relevant and reflective of real-world dynamics. The connection between external influences and shifts in curves is a crucial aspect of the topic and is expressed clearly.
#
# #### Adherence to Known Facts:
# The key points stated in the result adhere to well-established economic principles. The definitions, descriptions of shifts, and discussions surrounding equilibrium are consistent with the literature in economics and offer an accurate representation of how these concepts function.
#
# 4. **Real-World Analogies**:
#    - The inclusion of real-world analogies is beneficial for understanding—however, it's important that these analogies do not detract from the economic concepts they aim to illustrate. The mention of the bakery and concert ticket sales as analogies is widely relatable and serves to clarify the points being made.
#
# #### Potential Biases:
# There are no apparent biases in the explanation. The response focuses solely on the economic concepts without introducing subjective or controversial viewpoints. However, it's worth noting that relying too heavily on analogies could lead to misinterpretations if readers take them too literally. Clarity in their application is therefore essential to prevent any confusion.
#
# ### Conclusion:
# The evaluation of the responses indicates a consistent and reliable explanation of supply and demand in economics. The essential elements and foundational concepts are clearly articulated, logically arranged, and backed by credible economic theory. The response effectively combines the fundamental elements of the problem at hand, enhancing understanding while maintaining focus on the core economic significance. Overall, it fulfills the requirements of logical consistency, adherence to known facts, and presents a balanced perspective without superficial bias.
#
# To enhance reliability further, the response could emphasize the implications of these concepts on real-world markets even more, along with potential limitations or exceptions, providing a fuller context of supply and demand dynamics.
#
# --------------------------------------------------
#
# Problem: If a train travels at 60 km/h, how long will it take to cover 180 km?
